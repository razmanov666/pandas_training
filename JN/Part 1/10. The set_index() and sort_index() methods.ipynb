# %%
import pandas as pd

# reading the csv file
df_exams = pd.read_csv("StudentsPerformance.csv")
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # 1 Create index

# %%
import numpy as np
import random

# %%
# creating non repetitive values for the index
new_index = np.arange(0, 1000)

# %%
# shuffling the indexes
random.shuffle(new_index)
new_index
# Out:
# array([108, 305, 152, 180, 393, 323, 381,  10, 800, 431, 580, 253,  60,
#        857, 140, 889, 481, 508, 661, 873, 791, 506, 144, 859, 751, 450,
#        802, 974, 364, 877, 486, 187, 685, 382, 271, 371, 912, 359, 855,
#        796,  11, 898, 760, 550, 213,   3, 606, 854, 665, 841, 185, 130,
#        198, 703, 230, 923, 404, 215, 824, 710, 490, 210, 502, 254, 624,
#        688, 785,  78, 989,  24,  71, 874, 865,  12, 831,  57, 743, 598,
#         35,   2, 956,  40, 689, 484, 619, 587, 439, 459, 788, 719, 958,
#        516, 748, 686, 451, 636, 375, 982, 557, 922, 479, 792, 957, 846,
#        525, 289, 142, 162, 584, 591, 239, 847,  98, 786, 617, 630, 939,
#        106, 143, 480, 443,  51,  74, 300, 823, 907, 559, 902,  25,  37,
#         33, 160, 871, 698, 273, 851, 462, 157, 780, 597, 569,  21, 605,
#        257, 446, 250, 245, 416,  88,  50, 692, 633, 110, 567, 583, 505,
#         65, 769, 504, 427, 657, 722, 997, 266, 522, 862, 526,  15, 346,
#        306, 795, 723, 714, 272, 354,   4, 971, 138, 895, 975, 428, 133,
#        510, 411,  52, 423, 470, 511, 513, 356, 715, 656, 405, 313, 530,
#        994, 783, 836, 816, 647, 403, 246, 171, 507, 151, 545, 284, 325,
#        909, 927, 886, 818, 693, 483, 394, 931, 666, 612, 122, 252, 539,
#        279, 433, 259, 317,  31, 977, 613, 262, 475, 461, 799,  22, 333,
#         23, 341, 978, 670, 651, 132, 890, 365, 554, 214, 109, 637, 312,
#        677, 447, 946, 896, 749, 320, 814, 442, 920, 860, 546, 360, 822,
#        124, 930, 614,  67, 318, 650, 165, 118, 438, 244, 972, 521, 334,
#        301, 497, 960, 850, 296, 324, 887, 558, 515, 286, 217, 350, 280,
#        690, 884, 444, 434, 761, 643, 949, 663, 990, 172,  18, 669, 724,
#        146, 833, 340, 837, 348, 500, 845, 933, 330, 913, 639, 278, 779,
#        135, 219, 195, 695, 577, 261, 541, 468, 988, 295, 353, 414, 449,
#        561, 687, 615, 532, 291, 764, 547, 366, 464, 950, 232, 477, 773,
#        344,   9, 102, 241, 243, 789, 422, 852, 808, 166, 648, 548,  47,
#        835, 952,  82, 984, 489, 813, 829, 998, 983, 201, 879, 178, 849,
#        718, 864, 150, 638, 421, 713, 127,  16, 169, 553, 367, 750, 892,
#        208, 149, 358, 290, 739, 465, 756, 821, 967, 173, 534, 345, 732,
#         76,  66,  69, 921, 883, 370, 570, 668, 448, 441, 551, 362, 288,
#        793, 401, 520, 331, 311, 206, 571, 226, 453, 954, 113, 784, 380,
#        292, 941, 699, 867, 269, 126, 540, 625, 645, 174, 374, 275, 202,
#        276, 700, 839, 926, 885, 765, 373, 420, 746, 626, 379, 858, 734,
#        120,  54, 798, 806, 285, 332, 435, 179,  89, 572, 623, 566, 458,
#        838, 827, 671, 861, 938, 192, 738, 600, 596, 388, 476, 943, 134,
#        104, 878, 263,  90, 225, 767, 599, 901, 407, 308, 819, 270, 377,
#         87, 107, 682, 168, 942, 728,  55, 485, 531, 164, 512, 811,  63,
#        872,   6,  70, 642, 863, 228, 801, 747, 908, 247, 182, 897, 904,
#        585, 299, 996, 543, 255, 720, 139, 390, 321, 349, 771, 429, 980,
#         86,  94, 729, 492,  72, 768, 869,  46, 576, 400,  58, 925])

# %%
# create a new column with new index
df_exams['new_index'] = new_index
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      new_index
# 0          108
# 1          305
# 2          152
# 3          180
# 4          393
# ..         ...
# 995         46
# 996        576
# 997        400
# 998         58
# 999        925
#
# [1000 rows x 9 columns]

# %% [markdown]
# # 2 Set index

# %%
# set new_index column as index
# df_exams.set_index('new_index', inplace=True)
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 108        female        group B           bachelor's degree      standard
# 305        female        group C                some college      standard
# 152        female        group B             master's degree      standard
# 180          male        group A          associate's degree  free/reduced
# 393          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 46         female        group E             master's degree      standard
# 576          male        group C                 high school  free/reduced
# 400        female        group C                 high school  free/reduced
# 58         female        group D                some college      standard
# 925        female        group D                some college  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new_index
# 108                          none          72             72             74
# 305                     completed          69             90             88
# 152                          none          90             95             93
# 180                          none          47             57             44
# 393                          none          76             78             75
# ...                           ...         ...            ...            ...
# 46                      completed          88             99             95
# 576                          none          62             55             55
# 400                     completed          59             71             65
# 58                      completed          68             78             77
# 925                          none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # 3 Sort index

# %%
# sort dataframe by new index
df_exams.sort_index()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0          female        group B           bachelor's degree      standard
# 1          female        group E          associate's degree      standard
# 2          female        group E             master's degree      standard
# 3            male        group B          associate's degree      standard
# 4          female        group C             master's degree      standard
# ...           ...            ...                         ...           ...
# 995        female        group C          associate's degree      standard
# 996          male        group C          associate's degree      standard
# 997          male        group B             master's degree  free/reduced
# 998          male        group D                some college  free/reduced
# 999        female        group B           bachelor's degree  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new_index
# 0                       completed          66             74             81
# 1                       completed          93            100             95
# 2                            none          62             68             68
# 3                            none          65             54             57
# 4                       completed          81             91             87
# ...                           ...         ...            ...            ...
# 995                     completed          52             59             62
# 996                          none          62             65             58
# 997                          none          49             53             52
# 998                          none          59             62             61
# 999                          none          77             85             87
#
# [1000 rows x 8 columns]

# %%
# sort descending by index
df_exams.sort_index(ascending=False, inplace=True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 999        female        group B           bachelor's degree  free/reduced
# 998          male        group D                some college  free/reduced
# 997          male        group B             master's degree  free/reduced
# 996          male        group C          associate's degree      standard
# 995        female        group C          associate's degree      standard
# ...           ...            ...                         ...           ...
# 4          female        group C             master's degree      standard
# 3            male        group B          associate's degree      standard
# 2          female        group E             master's degree      standard
# 1          female        group E          associate's degree      standard
# 0          female        group B           bachelor's degree      standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 999                          none          77             85             87
# 998                          none          59             62             61
# 997                          none          49             53             52
# 996                          none          62             65             58
# 995                     completed          52             59             62
# ...                           ...         ...            ...            ...
# 4                       completed          81             91             87
# 3                            none          65             54             57
# 2                            none          62             68             68
# 1                       completed          93            100             95
# 0                       completed          66             74             81
#
# [1000 rows x 8 columns]
